# %%
# !python --version
# Out:
# Python 3.8.10

# %% [markdown]
# ## 1. Problem Statment

# %%
To predict the insurance value

# %% [markdown]
# ## 2. Data Collection

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df.head(2)
# Out:
#    Unnamed: 0  age  gender    bmi  children  smoker   charges
# 0           0   19       1  27.90         0       1  16884.92
# 1           1   18       0  33.77         1       0   1725.55

# %% [markdown]
# ## 3. EDA

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# age           0
# gender        0
# bmi           0
# children      0
# smoker        0
# charges       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1338 non-null   int64
#  1   age         1338 non-null   int64
#  2   gender      1338 non-null   int64
#  3   bmi         1338 non-null   float64
#  4   children    1338 non-null   int64
#  5   smoker      1338 non-null   int64
#  6   charges     1338 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %%
df['age']=df['age'].astype(float)
df['gender']=df['gender'].astype(float)
df['children']=df['children'].astype(float)
df['smoker']=df['smoker'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   float64
#  1   gender    1338 non-null   float64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   float64
#  4   smoker    1338 non-null   int32
#  5   charges   1338 non-null   float64
# dtypes: float64(5), int32(1)
# memory usage: 57.6 KB

# %%
del df['Unnamed: 0']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   charges   1338 non-null   float64
# dtypes: float64(2), int64(4)
# memory usage: 62.8 KB

# %% [markdown]
# ## 4. Feature Engineering

# %%
import seaborn as sns

sns.pairplot(df)

# %%
from scipy.stats import zscore

z_value = zscore(df['bmi'])
z_value
# Out:
# 0      -0.453320
# 1       0.509621
# 2       0.383307
# 3      -1.305531
# 4      -0.292556
#           ...
# 1333    0.050297
# 1334    0.206139
# 1335    1.014878
# 1336   -0.797813
# 1337   -0.261388
# Name: bmi, Length: 1338, dtype: float64

# %%
outlier = df['bmi'].loc[df['bmi']>z_value]
outlier
# Out:
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1338, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.scatter(x=df['bmi'],y=df['charges'])

# %%
plt.scatter(x=df['age'],y=df['bmi'])

# %% [markdown]
# ## 6. Model Training

# %%
x = df.drop(['charges'], axis=1)
y = df['charges']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=1)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1070, 5), (268, 5), (1070,), (268,))

# %%
pred_model = LinearRegression()

pred_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 7. Model Evaluation

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
lasso_model = Lasso(alpha=1.0)
lasso_model.fit(x_train,y_train)
# Out:
# Lasso()

# %%
ridge_model = Ridge()
ridge_model.fit(x_train,y_train)
# Out:
# Ridge()

# %%
y_pred = pred_model.predict(x_train)
y_pred
# Out:
# array([10390.47430046,  8975.05471645,  4378.90644627, ...,
#        37003.17057998, 30279.37564685, 12001.58136819])

# %%
# For Training Data

y_pred = pred_model.predict(x_train)

mse = mean_squared_error(y_train,y_pred)
print(f"Mean Squared Error = {mse}")

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")

mae = mean_absolute_error(y_train,y_pred)
print(f"Mean Absolute Error = {mae}")

r2 = r2_score(y_train,y_pred)
print(f"Root mean Squared Error = {r2}")
# Out:
# Mean Squared Error = 36949349.98719516
# Root Mean Squared Error = 6078.597699074611
# Mean Absolute Error = 4183.704305436104
# Root mean Squared Error = 0.7466601140999372

# %%
# For Testing Data

y_pred = pred_model.predict(x_test)

mse = mean_squared_error(y_test,y_pred)
print(f"Mean Squared Error = {mse}")

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")

mae = mean_absolute_error(y_test,y_pred)
print(f"Mean Absolute Error = {mae}")

r2 = r2_score(y_test,y_pred)
print(f"Root mean Squared Error = {r2}")
# Out:
# Mean Squared Error = 35699246.09854278
# Root Mean Squared Error = 5974.884609642498
# Mean Absolute Error = 4037.9524892426048
# Root mean Squared Error = 0.7608581783386867

# %% [markdown]
# ### User Input Function

# %%
x_train.head(1).T
# Out:
#            216
# age       53.0
# gender     1.0
# bmi       26.6
# children   0.0
# smoker     0.0

# %%
age = 53.0
gender = 1.0
bmi = 26.6
children = 0
smoker = 0

array = np.array([age,gender,bmi,children,smoker], ndmin=2)[0]
prediction = pred_model.predict(array)
prediction
# Out:
# C:\Users\Bhushan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10390.47430046])

# %% [markdown]
# ### Pickle file

# %%
import pickle

with open('model.pkl','wb') as file:
    pickle.dump(pred_model,file)
